# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load trained model
model = load_model("face_recognition_model.h5")
class_labels = ["Ahsam", "Maruf", "Saiba", "Shusmita"]
img_size = 224

# Haar Cascade for face detection
haar_cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(haar_cascade_path)

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(50, 50))

    for (x, y, w, h) in faces:
        face = frame[y:y+h, x:x+w]
        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face_resized = cv2.resize(face_rgb, (img_size, img_size))
        face_normalized = face_resized / 255.0
        face_input = np.expand_dims(face_normalized, axis=0)

        preds = model.predict(face_input, verbose=0)
        class_idx = np.argmax(preds)
        confidence = preds[0][class_idx] * 100

        if confidence >= 60:
            label = f"{class_labels[class_idx]} ({confidence:.1f}%)"
        else:
            label = "Unknown"

        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, label, (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 255), 2)

    cv2.imshow("Face Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\maruf\miniconda3\envs\tf_gpu\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 from tensorflow.keras.models import load_model
#       5 # Load trained model
# ----> 6 model = load_model("face_recognition_model.h5")
#       7 class_labels = ["Ahsam", "Maruf", "Saiba", "Shusmita"]
#       8 img_size = 224
#
# File ~\miniconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\miniconda3\envs\tf_gpu\lib\site-packages\keras\engine\input_layer.py:152, in InputLayer.__init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, type_spec, **kwargs)
#     150         input_shape = batch_input_shape[1:]
#     151 if kwargs:
# --> 152     raise ValueError(
#     153         f"Unrecognized keyword arguments: {list(kwargs.keys())}"
#     154     )
#     156 if sparse and ragged:
#     157     raise ValueError(
#     158         "Cannot set both sparse and ragged to True in a Keras input."
#     159     )
#
# ValueError: Unrecognized keyword arguments: ['batch_shape']
